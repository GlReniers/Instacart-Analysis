# %% [markdown]
# ## Exercise 4.7

# %%
# Importing pandas, numpy and os libraries
import pandas as pd
import numpy as np
import os

# %%
## Turning project folder path into a string
path = r'/Users/gwynreniers/Documents/Instacart Analysis'
path
# Out:
# '/Users/gwynreniers/Documents/Instacart Analysis'

# %%
# Import dataframes


df_ords_prods_comb = pd.read_pickle(os.path.join(path,'02 Data','Prepared Data','ords_prods_merged.pkl'))

# %%
df_ords_prods_comb.head()
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329        1    prior             1                   2
# 1   2398795        1    prior             2                   3
# 2    473747        1    prior             3                   3
# 3   2254736        1    prior             4                   4
# 4    431534        1    prior             5                   4
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  7                    15.0         196                  1
# 2                 12                    21.0         196                  1
# 3                  7                    29.0         196                  1
# 4                 15                    28.0         196                  1
#
#    reordered product_name  aisle_id  department_id  prices _merge
# ...

# %%
# droppping column eval_set since I didnt save it right
df.drop(columns = ['eval_set'])
# Out:
#         order_id  user_id  order_number  orders_day_of_week  \
# 0        2539329        1             1                   2
# 1        2398795        1             2                   3
# 2         473747        1             3                   3
# 3        2254736        1             4                   4
# 4         431534        1             5                   4
# ...          ...      ...           ...                 ...
# 999995   2836489   164627            14                   0
# 999996   1843600   164632             5                   1
# 999997    733106   164632             9                   2
# 999998   1650124   164632            17                   6
# 999999   3378258   164632            22                   6
#
#         order_hour_of_day  days_since_prior_order  product_id  \
# 0                       8                     NaN         196
# 1                       7                    15.0         196
# ...

# %%
df = df_ords_prods_comb[:1000000]
df
# Out:
#         order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0        2539329        1    prior             1                   2
# 1        2398795        1    prior             2                   3
# 2         473747        1    prior             3                   3
# 3        2254736        1    prior             4                   4
# 4         431534        1    prior             5                   4
# ...          ...      ...      ...           ...                 ...
# 999995   2836489   164627    prior            14                   0
# 999996   1843600   164632    prior             5                   1
# 999997    733106   164632    prior             9                   2
# 999998   1650124   164632    prior            17                   6
# 999999   3378258   164632    prior            22                   6
#
#         order_hour_of_day  days_since_prior_order  product_id  \
# 0                       8                     NaN         196
# ...

# %%
#define a function

def price_label(row):
    
    if row['prices'] <= 5:
        return 'Low-range product'
    elif (row['prices'] > 5) and (row['prices'] <= 15):
        return 'Mid-range product'
    elif row['prices'] > 15:
         return 'High range'
    else: return 'Not enough data'

# %%
#apply the function
df['price_range'] = df.apply(price_label, axis=1)
# Out:
# /var/folders/sr/4vbhyt1x1nxfjqq_tpssnnzc0000gn/T/ipykernel_13854/748875041.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis=1)

# %%
df['price_range'].value_counts(dropna = False)
# Out:
# Mid-range product    756450
# Low-range product    243550
# Name: price_range, dtype: int64

# %%
df['prices'].max()
# Out:
# 14.8

# %%
df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'
# Out:
# /var/folders/sr/4vbhyt1x1nxfjqq_tpssnnzc0000gn/T/ipykernel_13854/2857404532.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df.loc[df['prices'] <= 5, 'price_range_loc'] = 'low-range prodcut'

# %%
df['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid-range product    756450
# low-range prodcut    243550
# Name: price_range_loc, dtype: int64

# %%
df_ords_prods_comb.loc[df_ords_prods_comb['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %% [markdown]
# df_ords_prods_comb.loc[ords_prods_comb['prices'] > 15. 'price_range_loc'] = 'High-range product'

# %%
df_ords_prods_comb.loc[(df_ords_prods_comb['prices'] <= 15) & (df_ords_prods_comb['prices'] > 5),'price_range_loc'] = 'Mid-range product'

# %%
df_ords_prods_comb.loc[df_ords_prods_comb['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df_ords_prods_comb['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid-range product     21860860
# Low-range product     10126321
# High-range product      417678
# Name: price_range_loc, dtype: int64

# %%
df_ords_prods_comb['orders_day_of_week'].value_counts(dropna = False)
# Out:
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: orders_day_of_week, dtype: int64

# %%
result = []
for value in df_ords_prods_comb["orders_day_of_week"]:
    if value == 0:
        result.append("Busiest Day")
    elif value == 4:
        result.append("Least busy")
    else:
        result.append("Regularly Busy")

# %%
result
# Out:
# ['Regularly Busy',
#  'Regularly Busy',
#  'Regularly Busy',
#  'Least busy',
#  'Least busy',
#  'Regularly Busy',
#  'Regularly Busy',
#  'Regularly Busy',
#  'Regularly Busy',
#  'Least busy',
#  'Regularly Busy',
#  'Regularly Busy',
#  'Regularly Busy',
#  'Regularly Busy',
#  'Regularly Busy',
#  'Regularly Busy',
#  'Regularly Busy',
#  'Least busy',
#  'Regularly Busy',
#  'Regularly Busy',
#  'Regularly Busy',
#  'Least busy',
#  'Least busy',
#  'Regularly Busy',
#  'Regularly Busy',
#  'Regularly Busy',
#  'Regularly Busy',
#  'Regularly Busy',
#  'Regularly Busy',
#  'Regularly Busy',
#  'Regularly Busy',
#  'Regularly Busy',
#  'Regularly Busy',
#  'Regularly Busy',
#  'Regularly Busy',
#  'Regularly Busy',
#  'Regularly Busy',
#  'Regularly Busy',
#  'Regularly Busy',
#  'Regularly Busy',
#  'Regularly Busy',
#  'Regularly Busy',
#  'Regularly Busy',
#  'Regularly Busy',
#  'Regularly Busy',
#  'Regularly Busy',
#  'Regularly Busy',
#  'Regularly Busy',
# ...

# %%
df_ords_prods_comb['busiest_day'] = result

# %%
df_ords_prods_comb['busiest_day'].value_counts(dropna = False)
# Out:
# Regularly Busy    22416875
# Busiest Day        6204182
# Least busy         3783802
# Name: busiest_day, dtype: int64

# %% [markdown]
# ## 4.7 Task

# %%
#Change busiest day to plural: busiest days

result_2 = []

# %%
for value in df_ords_prods_comb['orders_day_of_week']:
    if value in [0,1]:
        result_2.append("Busiest Day")
    elif value in [3,4]:
        result_2.append("Least busy")
    else:
        result_2.append("Regularly busy")

# %%
# Creating new column for "Busiest Days" from results of above for-loop
df_ords_prods_comb['busiest_days'] = result_2
df_ords_prods_comb.head()
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329        1    prior             1                   2
# 1   2398795        1    prior             2                   3
# 2    473747        1    prior             3                   3
# 3   2254736        1    prior             4                   4
# 4    431534        1    prior             5                   4
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  7                    15.0         196                  1
# 2                 12                    21.0         196                  1
# 3                  7                    29.0         196                  1
# 4                 15                    28.0         196                  1
#
#    reordered product_name  aisle_id  department_id  prices _merge  \
# ...

# %%
#Counts of the new column for sorted days
df_ords_prods_comb['busiest_days'].value_counts(dropna = False)
# Out:
# Regularly busy    12916111
# Busiest Day       11864412
# Least busy         7624336
# Name: busiest_days, dtype: int64

# %%
#Checking the results against the output per day by summing single days
df_ords_prods_comb['orders_day_of_week'].value_counts(dropna = False)
# Out:
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: orders_day_of_week, dtype: int64

# %%
# Taking the sum of 0 (Saturday) and 1 (Sunday), 6204182 + 5660230 = 11864412 the sum is equal to the busiest day.
# Taking the sum of 3 (Tuesday) and 4 (Wednesday) 3840543 +3783802 = 7624336 the sum is equal to the least busy day.

# %%
# 4. Busiest hours: displaying orders per hour from most busy hour to least
df_ords_prods_comb['order_hour_of_day'].value_counts(dropna = False)
# Out:
# 10    2761760
# 11    2736140
# 14    2689136
# 15    2662144
# 13    2660954
# 12    2618532
# 16    2535202
# 9     2454203
# 17    2087654
# 8     1718118
# 18    1636502
# 19    1258305
# 20     976156
# 7      891054
# 21     795637
# 22     634225
# 23     402316
# 6      290493
# 0      218769
# 1      115700
# 5       87961
# 2       69375
# 4       53242
# 3       51281
# Name: order_hour_of_day, dtype: int64

# %%
# Create a loop for sorting the busiest hours
result_3 = []

for value in df_ords_prods_comb['order_hour_of_day']:
    if value >= 9and value <= 16:
        result_3.append("Most orders")
    elif value <= 6:
        result_3.append("Least orders")
    else:  
        result_3.append("Average orders")

# %%
#Creating a new column 'busiest_period_of_day' from results of for-loop
df_ords_prods_comb['Busiest_period_of_day'] = result_3
df_ords_prods_comb.head()
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329        1    prior             1                   2
# 1   2398795        1    prior             2                   3
# 2    473747        1    prior             3                   3
# 3   2254736        1    prior             4                   4
# 4    431534        1    prior             5                   4
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  7                    15.0         196                  1
# 2                 12                    21.0         196                  1
# 3                  7                    29.0         196                  1
# 4                 15                    28.0         196                  1
#
#    reordered product_name  aisle_id  department_id  prices _merge  \
# ...

# %%
#Count columns to determine periods: busiest/least busy/average
df_ords_prods_comb['Busiest_period_of_day'].value_counts(dropna = False)
# Out:
# Most orders       21118071
# Average orders    10399967
# Least orders        886821
# Name: Busiest_period_of_day, dtype: int64

# %%
## 7. Export
# Exporting data frame as pickle file to prepared data folder
df_ords_prods_comb.to_pickle(os.path.join(path,'02 Data', 'Prepared data','ords_prods_comb_updated.pkl'))
